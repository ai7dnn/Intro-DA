# %% [markdown]
# <a href="https://colab.research.google.com/github/ai7dnn/Intro-DA/blob/main/code/lecture01_02_03_notebook_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 교과목: 데이터분석입문 자료

# %% [markdown]
# # 파이썬 점검

# %%
import sys
sys.version
# Out:
# '3.13.15 (main, Aug  6 2026, 11:06:23) [GCC 11.4.0]'

# %%
import site
site.getsitepackages()
# Out:
# ['/usr/local/lib/python3.13/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/lib/python3.13/dist-packages']

# %% [markdown]
# # 파이썬 기초

# %% [markdown]
# ## 기본 자료형

# %%
type(1), type(3.5)
# Out:
# (int, float)

# %%
type('py'), type(True)
# Out:
# (str, bool)

# %%
type([]), type((1, ))
# Out:
# (list, tuple)

# %%
type({1:1, 2:4}), type({1, 2, 3})
# Out:
# (dict, set)

# %% [markdown]
# ## 연산자

# %%
3 + 4, 10 - 6, 3 * 5, 3 / 2, 3 // 2
# Out:
# (7, 4, 15, 1.5, 1)

# %%
3 ** 2, 10 % 3
# Out:
# (9, 1)

# %%
'py' + 'thon'
# Out:
# 'python'

# %%
'py' * 3
# Out:
# 'pypypy'

# %% [markdown]
# ## 내장 함수

# %%
divmod(10, 3)
# Out:
# (3, 1)

# %%
int('30') + float('3.56')
# Out:
# 33.56

# %%
abs(-10), bool(0)
# Out:
# (10, False)

# %%
chr(90), ord('a'), ord('A')
# Out:
# ('Z', 97, 65)

# %%
eval('3 + 4 * 5')
# Out:
# 23

# %%
s = 'py'
id(s)
# Out:
# 136427267374608

# %%
data = input('나이는? ')
data = int(data)
data
# Out:
# 나이는? 22
# 22
